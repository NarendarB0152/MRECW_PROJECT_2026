# %%
import tensorflow as tf

# %%
device = "/device:CPU:0"

# %%
# Dataset
import zipfile

z = zipfile.ZipFile('/content/Trash-Classifier-in-Python-using-Tensorflow.zip')

z.extractall()

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import math

dir_example = "Trash-Classifier-in-Python-using-Tensorflow/Data"

classes = os.listdir(dir_example)
print(classes)
# Out:
# ['Test', 'Train']

# %%
dir_example = "Trash-Classifier-in-Python-using-Tensorflow/Data/Train"

train_classes = os.listdir(dir_example)
print(train_classes)
# Out:
# ['metal', 'cardboard', 'plastic', 'glass', 'paper', 'trash']

# %%
dir_with_examples = 'Trash-Classifier-in-Python-using-Tensorflow/visualize'
files_per_row = 6
files_in_dir = os.listdir(dir_with_examples)
number_of_cols = files_per_row
number_of_rows = int(len(files_in_dir) / number_of_cols)

# Generate the subplots
fig, axs = plt.subplots(number_of_rows, number_of_cols)
fig.set_size_inches(20, 15, forward=True)

# Map each file to subplot
try:
  for i in range(0, len(files_in_dir)):
    file_name = files_in_dir[i]
    image = Image.open(f'{dir_with_examples}/{file_name}')
    row = math.floor(i / files_per_row)
    col = i % files_per_row
    axs[col].imshow(image)
    axs[col].axis('off')
except:
  pass
# Show the plot
plt.show()

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D
from tensorflow.keras.losses import sparse_categorical_crossentropy, binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Train'
test = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test'

# %%
train_generator = ImageDataGenerator(rescale = 1/255)

train_generator = train_generator.flow_from_directory(train,
                                                      target_size = (300,300),
                                                      batch_size = 32,
                                                      class_mode = 'sparse')

labels = (train_generator.class_indices)
print(labels,'\n')

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2186 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32,))

# %%
test_generator = ImageDataGenerator(rescale = 1./255)

test_generator = test_generator.flow_from_directory(test,
                                                    target_size = (300,300),
                                                    batch_size = 32,
                                                    class_mode = 'sparse')

test_labels = (test_generator.class_indices)
print(test_labels,'\n')

test_labels = dict((v,k) for k,v in test_labels.items())
print(test_labels)
# Out:
# Found 343 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
# !pip install oneDNN
# Out:
# Collecting oneDNN
#   Downloading onednn-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Collecting intel-opencl-rt==2025.* (from oneDNN)
#   Downloading intel_opencl_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting dpcpp-cpp-rt==2025.* (from oneDNN)
#   Downloading dpcpp_cpp_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: intel-openmp==2025.2.0 in /usr/local/lib/python3.11/dist-packages (from dpcpp-cpp-rt==2025.*->oneDNN) (2025.2.0)
# Collecting intel-sycl-rt==2025.2.0 (from dpcpp-cpp-rt==2025.*->oneDNN)
#   Downloading intel_sycl_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from intel-opencl-rt==2025.*->oneDNN) (2022.2.0)
# Collecting intel-cmplr-lic-rt==2025.* (from intel-opencl-rt==2025.*->oneDNN)
#   Downloading intel_cmplr_lic_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp==2025.2.0->dpcpp-cpp-rt==2025.*->oneDNN) (2025.2.0)
# Collecting intel-cmplr-lib-rt==2025.2.0 (from intel-sycl-rt==2025.2.0->dpcpp-cpp-rt==2025.*->oneDNN)
#   Downloading intel_cmplr_lib_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->intel-opencl-rt==2025.*->oneDNN) (1.4.0)
# Requirement already satisfied: umf==0.11.* in /usr/local/lib/python3.11/dist-packages (from intel-cmplr-lib-ur==2025.2.0->intel-openmp==2025.2.0->dpcpp-cpp-rt==2025.*->oneDNN) (0.11.0)
# Downloading onednn-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl (93.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 MB 9.5 MB/s eta 0:00:00
# Downloading dpcpp_cpp_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl (28 kB)
# Downloading intel_opencl_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl (193.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.0/193.0 MB 8.1 MB/s eta 0:00:00
# Downloading intel_cmplr_lic_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl (18 kB)
# Downloading intel_sycl_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl (113.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.8/113.8 MB 7.6 MB/s eta 0:00:00
# Downloading intel_cmplr_lib_rt-2025.2.0-py2.py3-none-manylinux_2_28_x86_64.whl (47.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: intel-cmplr-lic-rt, intel-cmplr-lib-rt, intel-opencl-rt, intel-sycl-rt, dpcpp-cpp-rt, oneDNN
# Successfully installed dpcpp-cpp-rt-2025.2.0 intel-cmplr-lib-rt-2025.2.0 intel-cmplr-lic-rt-2025.2.0 intel-opencl-rt-2025.2.0 intel-sycl-rt-2025.2.0 oneDNN-2025.2.0

# %%
import oneDNN as dnn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-14-680067888.py in <cell line: 0>()
# ----> 1 import oneDNN as dnn
#
# ModuleNotFoundError: No module named 'oneDNN'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
print(train_generator.class_indices)
Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('Labels.txt', 'w') as file:
  file.write(Labels)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '1'

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# Convolution blocks
model.add(Conv2D(32, kernel_size=(3,3), padding='same', input_shape=(300,300,3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

# Classification layers
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 300, 300, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 150, 150, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 150, 150, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 75, 75, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 43808)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     2,803,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,843,910 (10.85 MB)
#  Trainable params: 2,843,910 (10.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_generator,
          epochs=10,
          steps_per_epoch=2184//32)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 368s 5s/step - accuracy: 0.2257 - loss: 1.8571
# Epoch 2/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 260us/step - accuracy: 0.4062 - loss: 1.5224
# Epoch 3/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 358s 5s/step - accuracy: 0.3563 - loss: 1.5337
# Epoch 4/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 266us/step - accuracy: 0.3750 - loss: 1.4046
# Epoch 5/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 433s 6s/step - accuracy: 0.4128 - loss: 1.4270
# Epoch 6/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 363us/step - accuracy: 0.5312 - loss: 1.1692
# Epoch 7/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 421s 6s/step - accuracy: 0.4675 - loss: 1.2799
# Epoch 8/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 327us/step - accuracy: 0.4688 - loss: 1.4135
# Epoch 9/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 359s 5s/step - accuracy: 0.5196 - loss: 1.2431
# Epoch 10/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 200us/step - accuracy: 0.7188 - loss: 0.9905

# %%
import keras.utils as ku
import numpy as np

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/paper/paper522.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# Probability: 0.68423474
# Classified: paper
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 3.56 %
# GLASS : 2.25 %
# METAL : 23.43 %
# PAPER : 68.42 %
# PLASTIC : 0.63 %
# TRASH : 1.71 %

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/metal/metal386.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Probability: 0.28152463
# Classified: plastic
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 7.29 %
# GLASS : 25.74 %
# METAL : 13.21 %
# PAPER : 19.98 %
# PLASTIC : 28.15 %
# TRASH : 5.62 %

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/plastic/plastic430.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Probability: 0.50655913
# Classified: plastic
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 2.16 %
# GLASS : 19.33 %
# METAL : 7.87 %
# PAPER : 18.45 %
# PLASTIC : 50.66 %
# TRASH : 1.54 %

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/cardboard/cardboard355.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Probability: 0.9855254
# Classified: cardboard
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 98.55 %
# GLASS : 0.6 %
# METAL : 0.39 %
# PAPER : 0.02 %
# PLASTIC : 0.39 %
# TRASH : 0.05 %

# %%
model.save('modelnew.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
